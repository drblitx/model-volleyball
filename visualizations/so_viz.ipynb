# %% [markdown]
# ### Sophomore Year (2017) Visualizations

# %%
# module imports
import pandas as pd

# %%
# load in data
df = pd.read_csv('../data/full_matches.csv')

# %%
# filter out all other data
so = df[df['season'] == 'SO']

# %% [markdown]
# #### EDA

# %%
so.head()
# Out:
#            match_key  career_match_index career_stage season  \
# 36    SO_08-29_SAA_1                35.0        early     SO
# 37  SO_09-05_MARET_1                36.0        early     SO
# 38     SO_09-07_BW_1                37.0        early     SO
# 39   SO_09-09_AASD_1                38.0        early     SO
# 40   SO_09-09_AIDB_2                39.0          mid     SO
#
#     season_match_number        date day_of_week  week_of_season  \
# 36                    1  2017-08-29     Tuesday               1
# 37                    2  2017-09-05     Tuesday               2
# 38                    3  2017-09-07    Thursday               2
# 39                    4  2017-09-09    Saturday               2
# 40                    5  2017-09-09    Saturday               2
#
#     days_since_last_match  match_no  ...  receiving_errors  receiving_per_set  \
# 36                    291         1  ...               0.0                2.3
# ...
