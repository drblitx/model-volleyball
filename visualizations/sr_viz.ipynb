# %% [markdown]
# ### Senior Year (2019) Visualizations

# %%
# module imports
import pandas as pd

# %%
# load in data
df = pd.read_csv('../data/full_matches.csv')

# %%
# filter out all other data
sr = df[df['season'] == 'SR']

# %% [markdown]
# #### EDA

# %%
sr.head()
# Out:
#                match_key  career_match_index career_stage season  \
# 111     SR_08-29_MARET_1               107.0          mid     SR
# 112       SR_09-03_DCI_1               108.0          mid     SR
# 113        SR_09-05_CL_1               109.0          mid     SR
# 114      SR_09-07_BIHS_1               110.0          mid     SR
# 115  SR_09-07_HIGHLAND_2               111.0          mid     SR
#
#      season_match_number        date day_of_week  week_of_season  \
# 111                    1  2019-08-29    Thursday               1
# 112                    2  2019-09-03     Tuesday               1
# 113                    3  2019-09-05    Thursday               2
# 114                    4  2019-09-07    Saturday               2
# 115                    5  2019-09-07    Saturday               2
#
#      days_since_last_match  match_no  ...  receiving_errors  \
# 111                    296         1  ...               2.0
# ...
